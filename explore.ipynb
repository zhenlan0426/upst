# %%
# !python -m upst.scraper

# %%
from upst import load_clean
from analysis import plot_monthly_positions_by_department_clean
import matplotlib.pyplot as plt
df = load_clean(latest_only=True)

# %%
df = load_clean(latest_only=True)
fig = plot_monthly_positions_by_department_clean(df)
plt.show()
# Out:
# /home/zhenlan/Desktop/Projects/upst/analysis.py:293: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df_work['month_year'] = df_work['first_published'].dt.to_period('M')
