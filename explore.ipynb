# %%
from upst import scrape_sync, load_clean
df = load_clean()

# %%
df.head(100)
# Out:
#                                        absolute_url  \
# 0   https://careers.upstart.com/jobs?gh_jid=6948458
# 1   https://careers.upstart.com/jobs?gh_jid=6926082
# 2   https://careers.upstart.com/jobs?gh_jid=6922911
# 3   https://careers.upstart.com/jobs?gh_jid=6857642
# 4   https://careers.upstart.com/jobs?gh_jid=6854065
# ..                                              ...
# 87  https://careers.upstart.com/jobs?gh_jid=6816784
# 88  https://careers.upstart.com/jobs?gh_jid=6705666
# 89  https://careers.upstart.com/jobs?gh_jid=5751749
# 90  https://careers.upstart.com/jobs?gh_jid=6511641
# 91  https://careers.upstart.com/jobs?gh_jid=6855908
#
#                                       location                 updated_at  \
# 0                            Columbus, OH, USA  2025-06-09T03:11:06-04:00
# 1                       United States | Remote  2025-05-28T16:50:42-04:00
# 2                       United States | Remote  2025-05-27T16:14:15-04:00
# ...

# %%
df.offices[0]
# Out:
# "[{'child_ids': array([], dtype=object), 'id': 74688, 'location': 'Remote', 'name': 'Remote', 'parent_id': None}]"

# %%
df.data_compliance[0]
# Out:
# "[{'demographic_data_consent_applies': False, 'requires_consent': False, 'requires_processing_consent': False, 'requires_retention_consent': False, 'retention_period': None, 'type': 'gdpr'}]"
